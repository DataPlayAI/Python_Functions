# %% [markdown]
# **Syntax of a Python Function**

# %%
def data_play(play):
  #code
  return

# %% [markdown]
# **Function with no argument**

# %%
def hey_there():
  message = "Welcome Back"
  return message

# %% [markdown]
# **Function with one argument**

# %%
def hey(viewer):
  message = "Welcome Back"
  return message

# %% [markdown]
# **Function with many arguments**

# %%
def pay(no_hours, pay_per_hour):
  gross_pay = no_hours * pay_per_hour
  return gross_pay

# %% [markdown]
# **Calling a function**

# %%
def pay(no_hours, pay_per_hour):
  gross_pay = no_hours * pay_per_hour
  return gross_pay

pay_per_day = pay(5, 15)
print(pay_per_day)
# Out:
# 75
